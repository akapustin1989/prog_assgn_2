# %% [markdown]
# ## <span style=color:blue>DISCUSSION 6 - BENCHMARKING and VISUALIZATION Part 2</span>

# %%
import sys
import json
import csv
import yaml

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

import time
from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# %%
# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('benchmarking/')
import util_main as util

# %%
# test that utils.py has been imported well
util.hello_world()
# Out:
# Hello World!

# %%
# Load the env file 

dotenv_path = 'variables.env'
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
# Import the env variables

load_dotenv()

schema = os.getenv('DISC_6_SCHEMA')
port = os.getenv('DISC_6_PORT')
host = os.getenv('DISC_6_HOST')
database = os.getenv('DISC_6_DB')
password = os.getenv('DISC_6_PASSWORD')
connection = os.getenv('DISC_6_CONNECTION')

# %%
# Create the db engine 

db_eng = create_engine(f"postgresql+psycopg2://{connection}:{password}@{host}:{port}/{database}",
                       connect_args={'options': '-csearch_path={}'.format(schema)},
                       isolation_level = 'SERIALIZABLE')

print("Successfully created db engine.")
# Out:
# Successfully created db engine.

# %%
# Check to see the count of tables 

q = """select left(to_char(date, 'YYYY-MM-DD'),4) as year, count(*)
from reviews
group by year
order by year"""

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('2009', 56),
#  ('2010', 449),
#  ('2011', 1905),
#  ('2012', 3872),
#  ('2013', 7317),
#  ('2014', 14203),
#  ('2015', 28465),
#  ('2016', 42825),
#  ('2017', 39464),
#  ('2018', 41836),
#  ('2019', 41273),
#  ('2020', 10239),
#  ('2021', 18463),
#  ('2022', 26739),
#  ('2023', 22383),
#  ('2024', 511)]

# %%
# Create a function to build a query for reviews for each year

date_start = '2015-01-01'
date_end = '2015-12-31'

q = util.build_query_listings_reviews(date_start, date_end)

print(q)
# Out:
# SELECT DISTINCT l.id, l.name
# FROM listings l, reviews r
# WHERE l.id = r.listing_id
#   AND r.date >= '2015-01-01'
#   AND r.date <= '2015-12-31'
# ORDER BY l.id;

# %%
# Create function to build queries from the year 2009 to 2024

q_dict = {}

for yr in range(2009,2025):
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_reviews(date_start, date_end)
    
pprint.pp(q_dict)
# Out:
# {'listings_join_review_2009': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2009-01-01'\n"
#                               "  AND r.date <= '2009-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2010': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2010-01-01'\n"
#                               "  AND r.date <= '2010-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2011': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2011-01-01'\n"
#                               "  AND r.date <= '2011-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2012': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2012-01-01'\n"
#                               "  AND r.date <= '2012-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2013': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2013-01-01'\n"
#                               "  AND r.date <= '2013-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2014': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2014-01-01'\n"
#                               "  AND r.date <= '2014-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2015': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2015-01-01'\n"
#                               "  AND r.date <= '2015-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2016': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2016-01-01'\n"
#                               "  AND r.date <= '2016-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2017': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2017-01-01'\n"
#                               "  AND r.date <= '2017-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2018': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2018-01-01'\n"
#                               "  AND r.date <= '2018-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2019': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2019-01-01'\n"
#                               "  AND r.date <= '2019-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2020': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2020-01-01'\n"
#                               "  AND r.date <= '2020-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2021': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2021-01-01'\n"
#                               "  AND r.date <= '2021-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2022': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2022-01-01'\n"
#                               "  AND r.date <= '2022-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2023': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2023-01-01'\n"
#                               "  AND r.date <= '2023-12-31'\n"
#                               'ORDER BY l.id;',
#  'listings_join_review_2024': 'SELECT DISTINCT l.id, l.name\n'
#                               'FROM listings l, reviews r \n'
#                               'WHERE l.id = r.listing_id\n'
#                               "  AND r.date >= '2024-01-01'\n"
#                               "  AND r.date <= '2024-12-31'\n"
#                               'ORDER BY l.id;'}

# %%
# Create a function to calculate the performance of a single query from q_dict

count = 10

time_list = []
for i in range(0,count):
    time_start = datetime.now()
    # Open new db connection for each execution of the query to avoid multithreading
    with db_eng.connect() as conn:
        df = pd.read_sql(q_dict['listings_join_review_2015'], con=conn)

    time_end = datetime.now()
    diff = util.time_diff(time_start, time_end)
    time_list.append(diff)

pprint.pp(time_list)
print('mean', round(sum(time_list)/len(time_list), 4), 'min', \
        round(min(time_list), 4), 'max', \
        round(max(time_list), 4), 'std', \
        round(np.std(time_list), 4))
# Out:
# [0.117457,
#  0.090982,
#  0.095872,
#  0.087447,
#  0.085363,
#  0.088673,
#  0.090825,
#  0.164834,
#  0.14137,
#  0.124496]
# mean 0.1087 min 0.0854 max 0.1648 std 0.026

# %%
# Adding and dropping indexes in the table reviews 

q_create_date_in_reviews = '''
BEGIN TRANSACTION;
CREATE INDEX IF NOT EXISTS date_in_reviews
ON reviews(date);
END TRANSACTION;
'''

q_drop_date_in_reviews = '''
BEGIN TRANSACTION;
DROP INDEX IF EXISTS date_in_reviews;
END TRANSACTION;
'''

q_show_indexes_for_reviews = '''
select *
from pg_indexes
where tablename = 'reviews';
'''


with db_eng.connect() as conn:
    conn.execute(sql_text(q_create_date_in_reviews))
    result_reviews_add = conn.execute(sql_text(q_show_indexes_for_reviews))
    print('The set of indexes on reviews is: ')
    print(result_reviews_add.all())
# Out:
# The set of indexes on reviews is:
# [('new_york_city', 'reviews', 'date_in_reviews', None, 'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)')]

# %%
# Calculate statistics for each year

#Initialize the count to 20
count = 20

perf_details = {}
perf_details['with_index'] = {}

# Iterate through all the queries in q_dict
for year, sql_query in q_dict.items():
    time_list = []
    for i in range(count): 
        time_start = datetime.now()

        with db_eng.connect() as conn:
            df = pd.read_sql(sql_query, con=conn)

        time_end = datetime.now()
        # Calulate the time difference
        diff = util.time_diff(time_start, time_end)
        time_list.append(diff)

    # Splitting the string to get the year
    parts = year.split('_')
    curr_year = parts[-1]

    # Calulcate the metrics
    perf_profile = {
        'avg': round(sum(time_list) / len(time_list), 4),
        'min': round(min(time_list), 4),
        'max': round(max(time_list), 4),
        'std': round(np.std(time_list), 4)
    }

    # Add metrics according to the year
    perf_details['with_index'][curr_year] = perf_profile

print(perf_details)
# Out:
# {'with_index': {'2009': {'avg': 0.0185, 'min': 0.0135, 'max': 0.0291, 'std': 0.0032}, '2010': {'avg': 0.0175, 'min': 0.0126, 'max': 0.0223, 'std': 0.0028}, '2011': {'avg': 0.0222, 'min': 0.0103, 'max': 0.0332, 'std': 0.004}, '2012': {'avg': 0.0245, 'min': 0.0171, 'max': 0.035, 'std': 0.0049}, '2013': {'avg': 0.0358, 'min': 0.023, 'max': 0.116, 'std': 0.0192}, '2014': {'avg': 0.0455, 'min': 0.0349, 'max': 0.0789, 'std': 0.0107}, '2015': {'avg': 0.0777, 'min': 0.0641, 'max': 0.109, 'std': 0.011}, '2016': {'avg': 0.0681, 'min': 0.0488, 'max': 0.1063, 'std': 0.0169}, '2017': {'avg': 0.1112, 'min': 0.0923, 'max': 0.1409, 'std': 0.0146}, '2018': {'avg': 0.0541, 'min': 0.0442, 'max': 0.0784, 'std': 0.0096}, '2019': {'avg': 0.0473, 'min': 0.0399, 'max': 0.0945, 'std': 0.0123}, '2020': {'avg': 0.0349, 'min': 0.0221, 'max': 0.0859, 'std': 0.0125}, '2021': {'avg': 0.0424, 'min': 0.028, 'max': 0.065, 'std': 0.0077}, '2022': {'avg': 0.0663, 'min': 0.0469, 'max': 0.0905, 'std': 0.0121}, '2023': {'avg': 0.0512, 'min': 0.0387, 'max': 0.083, 'std': 0.0102}, '2024': {'avg': 0.0107, 'min': 0.0097, 'max': 0.013, 'std': 0.0008}}}

# %%
# Create a seperate function for the above and put it in the util file.
# Run it again to be sure  

count = 20

perf_details = {}

perf_details['with_index'] = util.calc_time_diff_per_year(db_eng, count, q_dict)

pp = pprint.PrettyPrinter(indent=4)

pp.pprint(perf_details)
# Out:
# {   'with_index': {   '2009': {   'avg': 0.0105,
#                                   'max': 0.0178,
#                                   'min': 0.0084,
#                                   'std': 0.0021},
#                       '2010': {   'avg': 0.0111,
#                                   'max': 0.0199,
#                                   'min': 0.0094,
#                                   'std': 0.0022},
#                       '2011': {   'avg': 0.0133,
#                                   'max': 0.0198,
#                                   'min': 0.0114,
#                                   'std': 0.0019},
#                       '2012': {   'avg': 0.018,
#                                   'max': 0.0314,
#                                   'min': 0.014,
#                                   'std': 0.0047},
#                       '2013': {   'avg': 0.025,
#                                   'max': 0.0349,
#                                   'min': 0.0204,
#                                   'std': 0.0044},
#                       '2014': {   'avg': 0.0406,
#                                   'max': 0.0592,
#                                   'min': 0.0347,
#                                   'std': 0.0058},
#                       '2015': {   'avg': 0.0803,
#                                   'max': 0.1259,
#                                   'min': 0.056,
#                                   'std': 0.0176},
#                       '2016': {   'avg': 0.0572,
#                                   'max': 0.0819,
#                                   'min': 0.0469,
#                                   'std': 0.0097},
#                       '2017': {   'avg': 0.1102,
#                                   'max': 0.1591,
#                                   'min': 0.0905,
#                                   'std': 0.019},
#                       '2018': {   'avg': 0.0584,
#                                   'max': 0.1012,
#                                   'min': 0.0394,
#                                   'std': 0.0134},
#                       '2019': {   'avg': 0.0485,
#                                   'max': 0.0757,
#                                   'min': 0.0313,
#                                   'std': 0.0109},
#                       '2020': {   'avg': 0.0313,
#                                   'max': 0.042,
#                                   'min': 0.0287,
#                                   'std': 0.003},
#                       '2021': {   'avg': 0.0433,
#                                   'max': 0.0822,
#                                   'min': 0.0312,
#                                   'std': 0.01},
#                       '2022': {   'avg': 0.0598,
#                                   'max': 0.0833,
#                                   'min': 0.0492,
#                                   'std': 0.009},
#                       '2023': {   'avg': 0.0507,
#                                   'max': 0.0889,
#                                   'min': 0.0424,
#                                   'std': 0.0098},
#                       '2024': {   'avg': 0.0119,
#                                   'max': 0.0154,
#                                   'min': 0.0095,
#                                   'std': 0.0013}}}

# %%
# Drop the index on date in reviews

with db_eng.connect() as conn:
    conn.execute(sql_text(q_drop_date_in_reviews))

# %%
# Calculate the same metrics for review without the index

perf_details['without_index'] = util.calc_time_diff_per_year(db_eng, count, q_dict)

pp.pprint(perf_details)
# Out:
# {   'with_index': {   '2009': {   'avg': 0.0105,
#                                   'max': 0.0178,
#                                   'min': 0.0084,
#                                   'std': 0.0021},
#                       '2010': {   'avg': 0.0111,
#                                   'max': 0.0199,
#                                   'min': 0.0094,
#                                   'std': 0.0022},
#                       '2011': {   'avg': 0.0133,
#                                   'max': 0.0198,
#                                   'min': 0.0114,
#                                   'std': 0.0019},
#                       '2012': {   'avg': 0.018,
#                                   'max': 0.0314,
#                                   'min': 0.014,
#                                   'std': 0.0047},
#                       '2013': {   'avg': 0.025,
#                                   'max': 0.0349,
#                                   'min': 0.0204,
#                                   'std': 0.0044},
#                       '2014': {   'avg': 0.0406,
#                                   'max': 0.0592,
#                                   'min': 0.0347,
#                                   'std': 0.0058},
#                       '2015': {   'avg': 0.0803,
#                                   'max': 0.1259,
#                                   'min': 0.056,
#                                   'std': 0.0176},
#                       '2016': {   'avg': 0.0572,
#                                   'max': 0.0819,
#                                   'min': 0.0469,
#                                   'std': 0.0097},
#                       '2017': {   'avg': 0.1102,
#                                   'max': 0.1591,
#                                   'min': 0.0905,
#                                   'std': 0.019},
#                       '2018': {   'avg': 0.0584,
#                                   'max': 0.1012,
#                                   'min': 0.0394,
#                                   'std': 0.0134},
#                       '2019': {   'avg': 0.0485,
#                                   'max': 0.0757,
#                                   'min': 0.0313,
#                                   'std': 0.0109},
#                       '2020': {   'avg': 0.0313,
#                                   'max': 0.042,
#                                   'min': 0.0287,
#                                   'std': 0.003},
#                       '2021': {   'avg': 0.0433,
#                                   'max': 0.0822,
#                                   'min': 0.0312,
#                                   'std': 0.01},
#                       '2022': {   'avg': 0.0598,
#                                   'max': 0.0833,
#                                   'min': 0.0492,
#                                   'std': 0.009},
#                       '2023': {   'avg': 0.0507,
#                                   'max': 0.0889,
#                                   'min': 0.0424,
#                                   'std': 0.0098},
#                       '2024': {   'avg': 0.0119,
#                                   'max': 0.0154,
#                                   'min': 0.0095,
#                                   'std': 0.0013}},
#     'without_index': {   '2009': {   'avg': 0.0706,
#                                      'max': 0.1559,
#                                      'min': 0.0435,
#                                      'std': 0.0354},
#                          '2010': {   'avg': 0.0664,
#                                      'max': 0.1589,
#                                      'min': 0.0537,
#                                      'std': 0.028},
#                          '2011': {   'avg': 0.0687,
#                                      'max': 0.1615,
#                                      'min': 0.0421,
#                                      'std': 0.0305},
#                          '2012': {   'avg': 0.076,
#                                      'max': 0.1653,
#                                      'min': 0.0557,
#                                      'std': 0.0282},
#                          '2013': {   'avg': 0.0708,
#                                      'max': 0.1593,
#                                      'min': 0.0544,
#                                      'std': 0.03},
#                          '2014': {   'avg': 0.091,
#                                      'max': 0.1762,
#                                      'min': 0.0711,
#                                      'std': 0.0255},
#                          '2015': {   'avg': 0.1123,
#                                      'max': 0.159,
#                                      'min': 0.0948,
#                                      'std': 0.0188},
#                          '2016': {   'avg': 0.0846,
#                                      'max': 0.1211,
#                                      'min': 0.0671,
#                                      'std': 0.0154},
#                          '2017': {   'avg': 0.1185,
#                                      'max': 0.2038,
#                                      'min': 0.0937,
#                                      'std': 0.0294},
#                          '2018': {   'avg': 0.1326,
#                                      'max': 0.1752,
#                                      'min': 0.0988,
#                                      'std': 0.0196},
#                          '2019': {   'avg': 0.123,
#                                      'max': 0.1793,
#                                      'min': 0.0985,
#                                      'std': 0.0236},
#                          '2020': {   'avg': 0.0861,
#                                      'max': 0.1643,
#                                      'min': 0.062,
#                                      'std': 0.0306},
#                          '2021': {   'avg': 0.1,
#                                      'max': 0.1687,
#                                      'min': 0.0641,
#                                      'std': 0.0293},
#                          '2022': {   'avg': 0.1083,
#                                      'max': 0.164,
#                                      'min': 0.0788,
#                                      'std': 0.0258},
#                          '2023': {   'avg': 0.0887,
#                                      'max': 0.1166,
#                                      'min': 0.0725,
#                                      'std': 0.0118},
#                          '2024': {   'avg': 0.0668,
#                                      'max': 0.1851,
#                                      'min': 0.0476,
#                                      'std': 0.0348}}}

# %%
# We need a way to save this data somewhere....save it in a json file (pref_data.json)

perf_file = 'perf_data-main.json'

try:
    old_perf_summary = util.fetch_perf_data(perf_file)
    print('Successfully read file perf_data/' + perf_file)
except:
    print('Not successful in finding file perf_data/' + perf_file + '; so creating it')
    old_perf_summary = {}
    util.write_perf_data(perf_details, perf_file)
    
util.write_perf_data(perf_details, perf_file)

# With this we have completed the benchmarking test using a single index on the date column of the reviews table
# However let's include visualization to see our results
# Out:
# Successfully read file perf_data/perf_data-main.json

# %%
# Load JSON data from a file
with open('perf_data/perf_data-main.json', 'r') as file:
    data = json.load(file)

# Printing the loaded file
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "with_index": {
#         "2009": {
#             "avg": 0.0105,
#             "max": 0.0178,
#             "min": 0.0084,
#             "std": 0.0021
#         },
#         "2010": {
#             "avg": 0.0111,
#             "max": 0.0199,
#             "min": 0.0094,
#             "std": 0.0022
#         },
#         "2011": {
#             "avg": 0.0133,
#             "max": 0.0198,
#             "min": 0.0114,
#             "std": 0.0019
#         },
#         "2012": {
#             "avg": 0.018,
#             "max": 0.0314,
#             "min": 0.014,
#             "std": 0.0047
#         },
#         "2013": {
#             "avg": 0.025,
#             "max": 0.0349,
#             "min": 0.0204,
#             "std": 0.0044
#         },
#         "2014": {
#             "avg": 0.0406,
#             "max": 0.0592,
#             "min": 0.0347,
#             "std": 0.0058
#         },
#         "2015": {
#             "avg": 0.0803,
#             "max": 0.1259,
#             "min": 0.056,
#             "std": 0.0176
#         },
#         "2016": {
#             "avg": 0.0572,
#             "max": 0.0819,
#             "min": 0.0469,
#             "std": 0.0097
#         },
#         "2017": {
#             "avg": 0.1102,
#             "max": 0.1591,
#             "min": 0.0905,
#             "std": 0.019
#         },
#         "2018": {
#             "avg": 0.0584,
#             "max": 0.1012,
#             "min": 0.0394,
#             "std": 0.0134
#         },
#         "2019": {
#             "avg": 0.0485,
#             "max": 0.0757,
#             "min": 0.0313,
#             "std": 0.0109
#         },
#         "2020": {
#             "avg": 0.0313,
#             "max": 0.042,
#             "min": 0.0287,
#             "std": 0.003
#         },
#         "2021": {
#             "avg": 0.0433,
#             "max": 0.0822,
#             "min": 0.0312,
#             "std": 0.01
#         },
#         "2022": {
#             "avg": 0.0598,
#             "max": 0.0833,
#             "min": 0.0492,
#             "std": 0.009
#         },
#         "2023": {
#             "avg": 0.0507,
#             "max": 0.0889,
#             "min": 0.0424,
#             "std": 0.0098
#         },
#         "2024": {
#             "avg": 0.0119,
#             "max": 0.0154,
#             "min": 0.0095,
#             "std": 0.0013
#         }
#     },
#     "without_index": {
#         "2009": {
#             "avg": 0.0706,
#             "max": 0.1559,
#             "min": 0.0435,
#             "std": 0.0354
#         },
#         "2010": {
#             "avg": 0.0664,
#             "max": 0.1589,
#             "min": 0.0537,
#             "std": 0.028
#         },
#         "2011": {
#             "avg": 0.0687,
#             "max": 0.1615,
#             "min": 0.0421,
#             "std": 0.0305
#         },
#         "2012": {
#             "avg": 0.076,
#             "max": 0.1653,
#             "min": 0.0557,
#             "std": 0.0282
#         },
#         "2013": {
#             "avg": 0.0708,
#             "max": 0.1593,
#             "min": 0.0544,
#             "std": 0.03
#         },
#         "2014": {
#             "avg": 0.091,
#             "max": 0.1762,
#             "min": 0.0711,
#             "std": 0.0255
#         },
#         "2015": {
#             "avg": 0.1123,
#             "max": 0.159,
#             "min": 0.0948,
#             "std": 0.0188
#         },
#         "2016": {
#             "avg": 0.0846,
#             "max": 0.1211,
#             "min": 0.0671,
#             "std": 0.0154
#         },
#         "2017": {
#             "avg": 0.1185,
#             "max": 0.2038,
#             "min": 0.0937,
#             "std": 0.0294
#         },
#         "2018": {
#             "avg": 0.1326,
#             "max": 0.1752,
#             "min": 0.0988,
#             "std": 0.0196
#         },
#         "2019": {
#             "avg": 0.123,
#             "max": 0.1793,
#             "min": 0.0985,
#             "std": 0.0236
#         },
#         "2020": {
#             "avg": 0.0861,
#             "max": 0.1643,
#             "min": 0.062,
#             "std": 0.0306
#         },
#         "2021": {
#             "avg": 0.1,
#             "max": 0.1687,
#             "min": 0.0641,
#             "std": 0.0293
#         },
#         "2022": {
#             "avg": 0.1083,
#             "max": 0.164,
#             "min": 0.0788,
#             "std": 0.0258
#         },
#         "2023": {
#             "avg": 0.0887,
#             "max": 0.1166,
#             "min": 0.0725,
#             "std": 0.0118
#         },
#         "2024": {
#             "avg": 0.0668,
#             "max": 0.1851,
#             "min": 0.0476,
#             "std": 0.0348
#         }
#     }
# }

# %%
# Convert the json into dataframes

df_with_index = pd.DataFrame(data['with_index']).transpose()
df_without_index = pd.DataFrame(data['without_index']).transpose()

print(df_with_index)
print(df_without_index)
# Out:
#          avg     min     max     std
# 2009  0.0105  0.0084  0.0178  0.0021
# 2010  0.0111  0.0094  0.0199  0.0022
# 2011  0.0133  0.0114  0.0198  0.0019
# 2012  0.0180  0.0140  0.0314  0.0047
# 2013  0.0250  0.0204  0.0349  0.0044
# 2014  0.0406  0.0347  0.0592  0.0058
# 2015  0.0803  0.0560  0.1259  0.0176
# 2016  0.0572  0.0469  0.0819  0.0097
# 2017  0.1102  0.0905  0.1591  0.0190
# 2018  0.0584  0.0394  0.1012  0.0134
# 2019  0.0485  0.0313  0.0757  0.0109
# 2020  0.0313  0.0287  0.0420  0.0030
# 2021  0.0433  0.0312  0.0822  0.0100
# 2022  0.0598  0.0492  0.0833  0.0090
# 2023  0.0507  0.0424  0.0889  0.0098
# 2024  0.0119  0.0095  0.0154  0.0013
#          avg     min     max     std
# 2009  0.0706  0.0435  0.1559  0.0354
# 2010  0.0664  0.0537  0.1589  0.0280
# 2011  0.0687  0.0421  0.1615  0.0305
# 2012  0.0760  0.0557  0.1653  0.0282
# 2013  0.0708  0.0544  0.1593  0.0300
# 2014  0.0910  0.0711  0.1762  0.0255
# 2015  0.1123  0.0948  0.1590  0.0188
# 2016  0.0846  0.0671  0.1211  0.0154
# 2017  0.1185  0.0937  0.2038  0.0294
# 2018  0.1326  0.0988  0.1752  0.0196
# 2019  0.1230  0.0985  0.1793  0.0236
# 2020  0.0861  0.0620  0.1643  0.0306
# 2021  0.1000  0.0641  0.1687  0.0293
# 2022  0.1083  0.0788  0.1640  0.0258
# 2023  0.0887  0.0725  0.1166  0.0118
# 2024  0.0668  0.0476  0.1851  0.0348

# %%
# Plot to compare the performances with and without indexes with respect to average time

plt.figure(figsize=(14, 7))
index = range(len(df_with_index))
bar_width = 0.35

plt.bar(index, df_with_index['avg'], bar_width, label='With Index')
plt.bar([p + bar_width for p in index], df_without_index['avg'], bar_width, label='Without Index')

# Calculate and plot the average times for with_bm and without_bm
avg_time_with_index = df_with_index['avg'].mean()
avg_time_without_index = df_without_index['avg'].mean()

plt.axhline(y=avg_time_with_index, color='blue', linestyle='--', label=f'Avg. Time With Index ({avg_time_with_index:.4f})')
plt.axhline(y=avg_time_without_index, color='red', linestyle='--', label=f'Avg. Time Without Index ({avg_time_without_index:.4f})')

plt.xlabel('Year')
plt.ylabel('Average Time')
plt.title('Average Performance Comparison With and Without Indexing')
plt.xticks([p + bar_width / 2 for p in index], df_with_index.index)
plt.legend()
plt.show()

# %%
# Plot to compare the performances with and without indexes with respect to standard deviation

plt.figure(figsize=(14, 7))

# Plot standard deviations
plt.plot(df_with_index.index, df_with_index['std'], label='With Index', marker='o')
plt.plot(df_without_index.index, df_without_index['std'], label='Without Index', marker='x')

# Calculate and plot the average standard deviation for with_bm and without_bm
avg_std_with_index = df_with_index['std'].mean()
avg_std_without_index = df_without_index['std'].mean()

plt.axhline(y=avg_std_with_index, color='blue', linestyle='--', label=f'Avg. Std With Index ({avg_std_with_index:.4f})')
plt.axhline(y=avg_std_without_index, color='red', linestyle='--', label=f'Avg. Std Without Index ({avg_std_without_index:.4f})')

plt.xlabel('Year')
plt.ylabel('Standard Deviation of Time')
plt.title('Standard Deviation Comparison Over Years')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ## <span style=color:blue>Using Prog Assgmt 2 json files for Visualization</span>

# %%
# Using the json files from PA 2 ---- listings_join_reviews (You can find this in the Files section under PROG-ASSGMT-2)

# Load JSON data from a file
with open('perf_data/listings_join_reviews_on_mac_v02.json', 'r') as file:
    data_listings = json.load(file)

# Printing the loaded file
print(json.dumps(data_listings, indent=4, sort_keys=True))
# Out:
# {
#     "listings_join_reviews_2009": {
#         "__": {
#             "avg": 0.3367,
#             "exec_count": 50,
#             "max": 3.7037,
#             "min": 0.242,
#             "std": 0.4821,
#             "timestamp": "2024-05-10-18:31:16"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0143,
#             "exec_count": 50,
#             "max": 0.0223,
#             "min": 0.013,
#             "std": 0.0014,
#             "timestamp": "2024-05-10-18:31:18"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0144,
#             "exec_count": 50,
#             "max": 0.0176,
#             "min": 0.0132,
#             "std": 0.0008,
#             "timestamp": "2024-05-10-18:31:31"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2337,
#             "exec_count": 50,
#             "max": 0.2685,
#             "min": 0.219,
#             "std": 0.0119,
#             "timestamp": "2024-05-10-18:31:30"
#         }
#     },
#     "listings_join_reviews_2010": {
#         "__": {
#             "avg": 0.2415,
#             "exec_count": 50,
#             "max": 0.2777,
#             "min": 0.2316,
#             "std": 0.0112,
#             "timestamp": "2024-05-10-18:31:43"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0163,
#             "exec_count": 50,
#             "max": 0.0399,
#             "min": 0.0134,
#             "std": 0.0041,
#             "timestamp": "2024-05-10-18:31:45"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0154,
#             "exec_count": 50,
#             "max": 0.0215,
#             "min": 0.0137,
#             "std": 0.0014,
#             "timestamp": "2024-05-10-18:31:58"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2368,
#             "exec_count": 50,
#             "max": 0.2552,
#             "min": 0.2299,
#             "std": 0.0058,
#             "timestamp": "2024-05-10-18:31:57"
#         }
#     },
#     "listings_join_reviews_2011": {
#         "__": {
#             "avg": 0.2488,
#             "exec_count": 50,
#             "max": 0.2912,
#             "min": 0.2267,
#             "std": 0.0148,
#             "timestamp": "2024-05-10-18:32:11"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0168,
#             "exec_count": 50,
#             "max": 0.0227,
#             "min": 0.0155,
#             "std": 0.0011,
#             "timestamp": "2024-05-10-18:32:12"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0169,
#             "exec_count": 50,
#             "max": 0.0194,
#             "min": 0.0153,
#             "std": 0.0009,
#             "timestamp": "2024-05-10-18:32:26"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2442,
#             "exec_count": 50,
#             "max": 0.3138,
#             "min": 0.2322,
#             "std": 0.0134,
#             "timestamp": "2024-05-10-18:32:24"
#         }
#     },
#     "listings_join_reviews_2012": {
#         "__": {
#             "avg": 0.2493,
#             "exec_count": 50,
#             "max": 0.2818,
#             "min": 0.2354,
#             "std": 0.0094,
#             "timestamp": "2024-05-10-18:32:38"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.02,
#             "exec_count": 50,
#             "max": 0.0285,
#             "min": 0.0179,
#             "std": 0.0017,
#             "timestamp": "2024-05-10-18:32:40"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0193,
#             "exec_count": 50,
#             "max": 0.0235,
#             "min": 0.0177,
#             "std": 0.001,
#             "timestamp": "2024-05-10-18:32:54"
#         },
#         "__id_in_listings__": {
#             "avg": 0.248,
#             "exec_count": 50,
#             "max": 0.2627,
#             "min": 0.2353,
#             "std": 0.0068,
#             "timestamp": "2024-05-10-18:32:53"
#         }
#     },
#     "listings_join_reviews_2013": {
#         "__": {
#             "avg": 0.2447,
#             "exec_count": 50,
#             "max": 0.2777,
#             "min": 0.2343,
#             "std": 0.0087,
#             "timestamp": "2024-05-10-18:33:07"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0238,
#             "exec_count": 50,
#             "max": 0.0351,
#             "min": 0.0221,
#             "std": 0.0018,
#             "timestamp": "2024-05-10-18:33:09"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0246,
#             "exec_count": 50,
#             "max": 0.0346,
#             "min": 0.0226,
#             "std": 0.0021,
#             "timestamp": "2024-05-10-18:33:23"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2546,
#             "exec_count": 50,
#             "max": 0.3399,
#             "min": 0.2369,
#             "std": 0.0188,
#             "timestamp": "2024-05-10-18:33:21"
#         }
#     },
#     "listings_join_reviews_2014": {
#         "__": {
#             "avg": 0.2651,
#             "exec_count": 50,
#             "max": 0.3247,
#             "min": 0.2424,
#             "std": 0.0172,
#             "timestamp": "2024-05-10-18:33:36"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0344,
#             "exec_count": 50,
#             "max": 0.0773,
#             "min": 0.0307,
#             "std": 0.0068,
#             "timestamp": "2024-05-10-18:33:39"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0332,
#             "exec_count": 50,
#             "max": 0.0409,
#             "min": 0.0307,
#             "std": 0.0015,
#             "timestamp": "2024-05-10-18:33:54"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2552,
#             "exec_count": 50,
#             "max": 0.2744,
#             "min": 0.2369,
#             "std": 0.0076,
#             "timestamp": "2024-05-10-18:33:52"
#         }
#     },
#     "listings_join_reviews_2015": {
#         "__": {
#             "avg": 0.287,
#             "exec_count": 50,
#             "max": 0.4063,
#             "min": 0.2595,
#             "std": 0.0369,
#             "timestamp": "2024-05-10-18:34:08"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0533,
#             "exec_count": 50,
#             "max": 0.0862,
#             "min": 0.0495,
#             "std": 0.0049,
#             "timestamp": "2024-05-10-18:34:12"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.054,
#             "exec_count": 50,
#             "max": 0.0607,
#             "min": 0.0507,
#             "std": 0.0021,
#             "timestamp": "2024-05-10-18:34:30"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2956,
#             "exec_count": 50,
#             "max": 0.4164,
#             "min": 0.2655,
#             "std": 0.0331,
#             "timestamp": "2024-05-10-18:34:27"
#         }
#     },
#     "listings_join_reviews_2016": {
#         "__": {
#             "avg": 0.2924,
#             "exec_count": 50,
#             "max": 0.3335,
#             "min": 0.2747,
#             "std": 0.0142,
#             "timestamp": "2024-05-10-18:34:45"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0698,
#             "exec_count": 50,
#             "max": 0.1158,
#             "min": 0.064,
#             "std": 0.0118,
#             "timestamp": "2024-05-10-18:34:49"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0702,
#             "exec_count": 50,
#             "max": 0.1174,
#             "min": 0.0645,
#             "std": 0.0115,
#             "timestamp": "2024-05-10-18:35:08"
#         },
#         "__id_in_listings__": {
#             "avg": 0.2938,
#             "exec_count": 50,
#             "max": 0.3396,
#             "min": 0.2822,
#             "std": 0.0114,
#             "timestamp": "2024-05-10-18:35:04"
#         }
#     },
#     "listings_join_reviews_2017": {
#         "__": {
#             "avg": 0.3071,
#             "exec_count": 50,
#             "max": 0.3439,
#             "min": 0.2873,
#             "std": 0.0115,
#             "timestamp": "2024-05-10-18:35:24"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.1493,
#             "exec_count": 50,
#             "max": 0.1533,
#             "min": 0.1461,
#             "std": 0.0017,
#             "timestamp": "2024-05-10-18:35:32"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.1472,
#             "exec_count": 50,
#             "max": 0.153,
#             "min": 0.1441,
#             "std": 0.0016,
#             "timestamp": "2024-05-10-18:35:56"
#         },
#         "__id_in_listings__": {
#             "avg": 0.3127,
#             "exec_count": 50,
#             "max": 0.372,
#             "min": 0.2952,
#             "std": 0.0141,
#             "timestamp": "2024-05-10-18:35:47"
#         }
#     },
#     "listings_join_reviews_2018": {
#         "__": {
#             "avg": 0.6324,
#             "exec_count": 50,
#             "max": 0.6798,
#             "min": 0.6191,
#             "std": 0.0128,
#             "timestamp": "2024-05-10-18:36:27"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.1925,
#             "exec_count": 50,
#             "max": 0.2377,
#             "min": 0.1864,
#             "std": 0.0111,
#             "timestamp": "2024-05-10-18:36:38"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.1954,
#             "exec_count": 50,
#             "max": 0.2408,
#             "min": 0.1874,
#             "std": 0.0114,
#             "timestamp": "2024-05-10-18:37:20"
#         },
#         "__id_in_listings__": {
#             "avg": 0.6418,
#             "exec_count": 50,
#             "max": 0.6907,
#             "min": 0.6137,
#             "std": 0.0154,
#             "timestamp": "2024-05-10-18:37:10"
#         }
#     },
#     "listings_join_reviews_2019": {
#         "__": {
#             "avg": 0.6656,
#             "exec_count": 50,
#             "max": 0.7141,
#             "min": 0.6414,
#             "std": 0.0154,
#             "timestamp": "2024-05-10-18:37:54"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.2471,
#             "exec_count": 50,
#             "max": 0.293,
#             "min": 0.2354,
#             "std": 0.0153,
#             "timestamp": "2024-05-10-18:38:07"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.2485,
#             "exec_count": 50,
#             "max": 0.3145,
#             "min": 0.2355,
#             "std": 0.0157,
#             "timestamp": "2024-05-10-18:38:54"
#         },
#         "__id_in_listings__": {
#             "avg": 0.6747,
#             "exec_count": 50,
#             "max": 0.7234,
#             "min": 0.6522,
#             "std": 0.0178,
#             "timestamp": "2024-05-10-18:38:41"
#         }
#     },
#     "listings_join_reviews_2020": {
#         "__": {
#             "avg": 0.3097,
#             "exec_count": 50,
#             "max": 0.4472,
#             "min": 0.2876,
#             "std": 0.0284,
#             "timestamp": "2024-05-10-18:39:09"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.1437,
#             "exec_count": 50,
#             "max": 0.1897,
#             "min": 0.1343,
#             "std": 0.0135,
#             "timestamp": "2024-05-10-18:39:17"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.1431,
#             "exec_count": 50,
#             "max": 0.1888,
#             "min": 0.1349,
#             "std": 0.013,
#             "timestamp": "2024-05-10-18:39:40"
#         },
#         "__id_in_listings__": {
#             "avg": 0.3026,
#             "exec_count": 50,
#             "max": 0.3507,
#             "min": 0.2879,
#             "std": 0.0126,
#             "timestamp": "2024-05-10-18:39:32"
#         }
#     },
#     "listings_join_reviews_2021": {
#         "__": {
#             "avg": 0.6682,
#             "exec_count": 50,
#             "max": 0.7167,
#             "min": 0.646,
#             "std": 0.0162,
#             "timestamp": "2024-05-10-18:40:14"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.2252,
#             "exec_count": 50,
#             "max": 0.2736,
#             "min": 0.2144,
#             "std": 0.0154,
#             "timestamp": "2024-05-10-18:40:26"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.2226,
#             "exec_count": 50,
#             "max": 0.2659,
#             "min": 0.2127,
#             "std": 0.0132,
#             "timestamp": "2024-05-10-18:41:11"
#         },
#         "__id_in_listings__": {
#             "avg": 0.667,
#             "exec_count": 50,
#             "max": 0.7271,
#             "min": 0.646,
#             "std": 0.0167,
#             "timestamp": "2024-05-10-18:40:59"
#         }
#     },
#     "listings_join_reviews_2022": {
#         "__": {
#             "avg": 0.7161,
#             "exec_count": 50,
#             "max": 0.7645,
#             "min": 0.6857,
#             "std": 0.0197,
#             "timestamp": "2024-05-10-18:41:47"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.7292,
#             "exec_count": 50,
#             "max": 0.8028,
#             "min": 0.699,
#             "std": 0.0268,
#             "timestamp": "2024-05-10-18:42:24"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.7106,
#             "exec_count": 50,
#             "max": 0.7544,
#             "min": 0.6899,
#             "std": 0.0201,
#             "timestamp": "2024-05-10-18:43:36"
#         },
#         "__id_in_listings__": {
#             "avg": 0.7124,
#             "exec_count": 50,
#             "max": 0.7628,
#             "min": 0.6881,
#             "std": 0.0215,
#             "timestamp": "2024-05-10-18:43:00"
#         }
#     },
#     "listings_join_reviews_2023": {
#         "__": {
#             "avg": 0.7311,
#             "exec_count": 50,
#             "max": 0.7913,
#             "min": 0.6991,
#             "std": 0.0227,
#             "timestamp": "2024-05-10-18:44:12"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.725,
#             "exec_count": 50,
#             "max": 0.7886,
#             "min": 0.6954,
#             "std": 0.0251,
#             "timestamp": "2024-05-10-18:44:49"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.7345,
#             "exec_count": 50,
#             "max": 0.7841,
#             "min": 0.7015,
#             "std": 0.0251,
#             "timestamp": "2024-05-10-18:46:04"
#         },
#         "__id_in_listings__": {
#             "avg": 0.7357,
#             "exec_count": 50,
#             "max": 0.7964,
#             "min": 0.6997,
#             "std": 0.0247,
#             "timestamp": "2024-05-10-18:45:26"
#         }
#     },
#     "listings_join_reviews_2024": {
#         "__": {
#             "avg": 0.2575,
#             "exec_count": 50,
#             "max": 0.2977,
#             "min": 0.2401,
#             "std": 0.0121,
#             "timestamp": "2024-05-10-18:46:16"
#         },
#         "__datetime_in_reviews__": {
#             "avg": 0.0312,
#             "exec_count": 50,
#             "max": 0.0517,
#             "min": 0.0288,
#             "std": 0.0031,
#             "timestamp": "2024-05-10-18:46:19"
#         },
#         "__datetime_in_reviews__id_in_listings__": {
#             "avg": 0.0315,
#             "exec_count": 50,
#             "max": 0.0421,
#             "min": 0.0289,
#             "std": 0.0022,
#             "timestamp": "2024-05-10-18:46:34"
#         },
#         "__id_in_listings__": {
#             "avg": 0.26,
#             "exec_count": 50,
#             "max": 0.3024,
#             "min": 0.2451,
#             "std": 0.0116,
#             "timestamp": "2024-05-10-18:46:32"
#         }
#     }
# }

# %%
# Renaming the keys
data_listings_renamed = util.rename_keys(data_listings)

pp.pprint(data_listings_renamed)
# Out:
# {   '2009': {   '__': {   'avg': 0.3367,
#                           'exec_count': 50,
#                           'max': 3.7037,
#                           'min': 0.242,
#                           'std': 0.4821,
#                           'timestamp': '2024-05-10-18:31:16'},
#                 '__datetime_in_reviews__': {   'avg': 0.0143,
#                                                'exec_count': 50,
#                                                'max': 0.0223,
#                                                'min': 0.013,
#                                                'std': 0.0014,
#                                                'timestamp': '2024-05-10-18:31:18'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0144,
#                                                                'exec_count': 50,
#                                                                'max': 0.0176,
#                                                                'min': 0.0132,
#                                                                'std': 0.0008,
#                                                                'timestamp': '2024-05-10-18:31:31'},
#                 '__id_in_listings__': {   'avg': 0.2337,
#                                           'exec_count': 50,
#                                           'max': 0.2685,
#                                           'min': 0.219,
#                                           'std': 0.0119,
#                                           'timestamp': '2024-05-10-18:31:30'}},
#     '2010': {   '__': {   'avg': 0.2415,
#                           'exec_count': 50,
#                           'max': 0.2777,
#                           'min': 0.2316,
#                           'std': 0.0112,
#                           'timestamp': '2024-05-10-18:31:43'},
#                 '__datetime_in_reviews__': {   'avg': 0.0163,
#                                                'exec_count': 50,
#                                                'max': 0.0399,
#                                                'min': 0.0134,
#                                                'std': 0.0041,
#                                                'timestamp': '2024-05-10-18:31:45'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0154,
#                                                                'exec_count': 50,
#                                                                'max': 0.0215,
#                                                                'min': 0.0137,
#                                                                'std': 0.0014,
#                                                                'timestamp': '2024-05-10-18:31:58'},
#                 '__id_in_listings__': {   'avg': 0.2368,
#                                           'exec_count': 50,
#                                           'max': 0.2552,
#                                           'min': 0.2299,
#                                           'std': 0.0058,
#                                           'timestamp': '2024-05-10-18:31:57'}},
#     '2011': {   '__': {   'avg': 0.2488,
#                           'exec_count': 50,
#                           'max': 0.2912,
#                           'min': 0.2267,
#                           'std': 0.0148,
#                           'timestamp': '2024-05-10-18:32:11'},
#                 '__datetime_in_reviews__': {   'avg': 0.0168,
#                                                'exec_count': 50,
#                                                'max': 0.0227,
#                                                'min': 0.0155,
#                                                'std': 0.0011,
#                                                'timestamp': '2024-05-10-18:32:12'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0169,
#                                                                'exec_count': 50,
#                                                                'max': 0.0194,
#                                                                'min': 0.0153,
#                                                                'std': 0.0009,
#                                                                'timestamp': '2024-05-10-18:32:26'},
#                 '__id_in_listings__': {   'avg': 0.2442,
#                                           'exec_count': 50,
#                                           'max': 0.3138,
#                                           'min': 0.2322,
#                                           'std': 0.0134,
#                                           'timestamp': '2024-05-10-18:32:24'}},
#     '2012': {   '__': {   'avg': 0.2493,
#                           'exec_count': 50,
#                           'max': 0.2818,
#                           'min': 0.2354,
#                           'std': 0.0094,
#                           'timestamp': '2024-05-10-18:32:38'},
#                 '__datetime_in_reviews__': {   'avg': 0.02,
#                                                'exec_count': 50,
#                                                'max': 0.0285,
#                                                'min': 0.0179,
#                                                'std': 0.0017,
#                                                'timestamp': '2024-05-10-18:32:40'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0193,
#                                                                'exec_count': 50,
#                                                                'max': 0.0235,
#                                                                'min': 0.0177,
#                                                                'std': 0.001,
#                                                                'timestamp': '2024-05-10-18:32:54'},
#                 '__id_in_listings__': {   'avg': 0.248,
#                                           'exec_count': 50,
#                                           'max': 0.2627,
#                                           'min': 0.2353,
#                                           'std': 0.0068,
#                                           'timestamp': '2024-05-10-18:32:53'}},
#     '2013': {   '__': {   'avg': 0.2447,
#                           'exec_count': 50,
#                           'max': 0.2777,
#                           'min': 0.2343,
#                           'std': 0.0087,
#                           'timestamp': '2024-05-10-18:33:07'},
#                 '__datetime_in_reviews__': {   'avg': 0.0238,
#                                                'exec_count': 50,
#                                                'max': 0.0351,
#                                                'min': 0.0221,
#                                                'std': 0.0018,
#                                                'timestamp': '2024-05-10-18:33:09'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0246,
#                                                                'exec_count': 50,
#                                                                'max': 0.0346,
#                                                                'min': 0.0226,
#                                                                'std': 0.0021,
#                                                                'timestamp': '2024-05-10-18:33:23'},
#                 '__id_in_listings__': {   'avg': 0.2546,
#                                           'exec_count': 50,
#                                           'max': 0.3399,
#                                           'min': 0.2369,
#                                           'std': 0.0188,
#                                           'timestamp': '2024-05-10-18:33:21'}},
#     '2014': {   '__': {   'avg': 0.2651,
#                           'exec_count': 50,
#                           'max': 0.3247,
#                           'min': 0.2424,
#                           'std': 0.0172,
#                           'timestamp': '2024-05-10-18:33:36'},
#                 '__datetime_in_reviews__': {   'avg': 0.0344,
#                                                'exec_count': 50,
#                                                'max': 0.0773,
#                                                'min': 0.0307,
#                                                'std': 0.0068,
#                                                'timestamp': '2024-05-10-18:33:39'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0332,
#                                                                'exec_count': 50,
#                                                                'max': 0.0409,
#                                                                'min': 0.0307,
#                                                                'std': 0.0015,
#                                                                'timestamp': '2024-05-10-18:33:54'},
#                 '__id_in_listings__': {   'avg': 0.2552,
#                                           'exec_count': 50,
#                                           'max': 0.2744,
#                                           'min': 0.2369,
#                                           'std': 0.0076,
#                                           'timestamp': '2024-05-10-18:33:52'}},
#     '2015': {   '__': {   'avg': 0.287,
#                           'exec_count': 50,
#                           'max': 0.4063,
#                           'min': 0.2595,
#                           'std': 0.0369,
#                           'timestamp': '2024-05-10-18:34:08'},
#                 '__datetime_in_reviews__': {   'avg': 0.0533,
#                                                'exec_count': 50,
#                                                'max': 0.0862,
#                                                'min': 0.0495,
#                                                'std': 0.0049,
#                                                'timestamp': '2024-05-10-18:34:12'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.054,
#                                                                'exec_count': 50,
#                                                                'max': 0.0607,
#                                                                'min': 0.0507,
#                                                                'std': 0.0021,
#                                                                'timestamp': '2024-05-10-18:34:30'},
#                 '__id_in_listings__': {   'avg': 0.2956,
#                                           'exec_count': 50,
#                                           'max': 0.4164,
#                                           'min': 0.2655,
#                                           'std': 0.0331,
#                                           'timestamp': '2024-05-10-18:34:27'}},
#     '2016': {   '__': {   'avg': 0.2924,
#                           'exec_count': 50,
#                           'max': 0.3335,
#                           'min': 0.2747,
#                           'std': 0.0142,
#                           'timestamp': '2024-05-10-18:34:45'},
#                 '__datetime_in_reviews__': {   'avg': 0.0698,
#                                                'exec_count': 50,
#                                                'max': 0.1158,
#                                                'min': 0.064,
#                                                'std': 0.0118,
#                                                'timestamp': '2024-05-10-18:34:49'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0702,
#                                                                'exec_count': 50,
#                                                                'max': 0.1174,
#                                                                'min': 0.0645,
#                                                                'std': 0.0115,
#                                                                'timestamp': '2024-05-10-18:35:08'},
#                 '__id_in_listings__': {   'avg': 0.2938,
#                                           'exec_count': 50,
#                                           'max': 0.3396,
#                                           'min': 0.2822,
#                                           'std': 0.0114,
#                                           'timestamp': '2024-05-10-18:35:04'}},
#     '2017': {   '__': {   'avg': 0.3071,
#                           'exec_count': 50,
#                           'max': 0.3439,
#                           'min': 0.2873,
#                           'std': 0.0115,
#                           'timestamp': '2024-05-10-18:35:24'},
#                 '__datetime_in_reviews__': {   'avg': 0.1493,
#                                                'exec_count': 50,
#                                                'max': 0.1533,
#                                                'min': 0.1461,
#                                                'std': 0.0017,
#                                                'timestamp': '2024-05-10-18:35:32'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.1472,
#                                                                'exec_count': 50,
#                                                                'max': 0.153,
#                                                                'min': 0.1441,
#                                                                'std': 0.0016,
#                                                                'timestamp': '2024-05-10-18:35:56'},
#                 '__id_in_listings__': {   'avg': 0.3127,
#                                           'exec_count': 50,
#                                           'max': 0.372,
#                                           'min': 0.2952,
#                                           'std': 0.0141,
#                                           'timestamp': '2024-05-10-18:35:47'}},
#     '2018': {   '__': {   'avg': 0.6324,
#                           'exec_count': 50,
#                           'max': 0.6798,
#                           'min': 0.6191,
#                           'std': 0.0128,
#                           'timestamp': '2024-05-10-18:36:27'},
#                 '__datetime_in_reviews__': {   'avg': 0.1925,
#                                                'exec_count': 50,
#                                                'max': 0.2377,
#                                                'min': 0.1864,
#                                                'std': 0.0111,
#                                                'timestamp': '2024-05-10-18:36:38'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.1954,
#                                                                'exec_count': 50,
#                                                                'max': 0.2408,
#                                                                'min': 0.1874,
#                                                                'std': 0.0114,
#                                                                'timestamp': '2024-05-10-18:37:20'},
#                 '__id_in_listings__': {   'avg': 0.6418,
#                                           'exec_count': 50,
#                                           'max': 0.6907,
#                                           'min': 0.6137,
#                                           'std': 0.0154,
#                                           'timestamp': '2024-05-10-18:37:10'}},
#     '2019': {   '__': {   'avg': 0.6656,
#                           'exec_count': 50,
#                           'max': 0.7141,
#                           'min': 0.6414,
#                           'std': 0.0154,
#                           'timestamp': '2024-05-10-18:37:54'},
#                 '__datetime_in_reviews__': {   'avg': 0.2471,
#                                                'exec_count': 50,
#                                                'max': 0.293,
#                                                'min': 0.2354,
#                                                'std': 0.0153,
#                                                'timestamp': '2024-05-10-18:38:07'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.2485,
#                                                                'exec_count': 50,
#                                                                'max': 0.3145,
#                                                                'min': 0.2355,
#                                                                'std': 0.0157,
#                                                                'timestamp': '2024-05-10-18:38:54'},
#                 '__id_in_listings__': {   'avg': 0.6747,
#                                           'exec_count': 50,
#                                           'max': 0.7234,
#                                           'min': 0.6522,
#                                           'std': 0.0178,
#                                           'timestamp': '2024-05-10-18:38:41'}},
#     '2020': {   '__': {   'avg': 0.3097,
#                           'exec_count': 50,
#                           'max': 0.4472,
#                           'min': 0.2876,
#                           'std': 0.0284,
#                           'timestamp': '2024-05-10-18:39:09'},
#                 '__datetime_in_reviews__': {   'avg': 0.1437,
#                                                'exec_count': 50,
#                                                'max': 0.1897,
#                                                'min': 0.1343,
#                                                'std': 0.0135,
#                                                'timestamp': '2024-05-10-18:39:17'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.1431,
#                                                                'exec_count': 50,
#                                                                'max': 0.1888,
#                                                                'min': 0.1349,
#                                                                'std': 0.013,
#                                                                'timestamp': '2024-05-10-18:39:40'},
#                 '__id_in_listings__': {   'avg': 0.3026,
#                                           'exec_count': 50,
#                                           'max': 0.3507,
#                                           'min': 0.2879,
#                                           'std': 0.0126,
#                                           'timestamp': '2024-05-10-18:39:32'}},
#     '2021': {   '__': {   'avg': 0.6682,
#                           'exec_count': 50,
#                           'max': 0.7167,
#                           'min': 0.646,
#                           'std': 0.0162,
#                           'timestamp': '2024-05-10-18:40:14'},
#                 '__datetime_in_reviews__': {   'avg': 0.2252,
#                                                'exec_count': 50,
#                                                'max': 0.2736,
#                                                'min': 0.2144,
#                                                'std': 0.0154,
#                                                'timestamp': '2024-05-10-18:40:26'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.2226,
#                                                                'exec_count': 50,
#                                                                'max': 0.2659,
#                                                                'min': 0.2127,
#                                                                'std': 0.0132,
#                                                                'timestamp': '2024-05-10-18:41:11'},
#                 '__id_in_listings__': {   'avg': 0.667,
#                                           'exec_count': 50,
#                                           'max': 0.7271,
#                                           'min': 0.646,
#                                           'std': 0.0167,
#                                           'timestamp': '2024-05-10-18:40:59'}},
#     '2022': {   '__': {   'avg': 0.7161,
#                           'exec_count': 50,
#                           'max': 0.7645,
#                           'min': 0.6857,
#                           'std': 0.0197,
#                           'timestamp': '2024-05-10-18:41:47'},
#                 '__datetime_in_reviews__': {   'avg': 0.7292,
#                                                'exec_count': 50,
#                                                'max': 0.8028,
#                                                'min': 0.699,
#                                                'std': 0.0268,
#                                                'timestamp': '2024-05-10-18:42:24'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.7106,
#                                                                'exec_count': 50,
#                                                                'max': 0.7544,
#                                                                'min': 0.6899,
#                                                                'std': 0.0201,
#                                                                'timestamp': '2024-05-10-18:43:36'},
#                 '__id_in_listings__': {   'avg': 0.7124,
#                                           'exec_count': 50,
#                                           'max': 0.7628,
#                                           'min': 0.6881,
#                                           'std': 0.0215,
#                                           'timestamp': '2024-05-10-18:43:00'}},
#     '2023': {   '__': {   'avg': 0.7311,
#                           'exec_count': 50,
#                           'max': 0.7913,
#                           'min': 0.6991,
#                           'std': 0.0227,
#                           'timestamp': '2024-05-10-18:44:12'},
#                 '__datetime_in_reviews__': {   'avg': 0.725,
#                                                'exec_count': 50,
#                                                'max': 0.7886,
#                                                'min': 0.6954,
#                                                'std': 0.0251,
#                                                'timestamp': '2024-05-10-18:44:49'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.7345,
#                                                                'exec_count': 50,
#                                                                'max': 0.7841,
#                                                                'min': 0.7015,
#                                                                'std': 0.0251,
#                                                                'timestamp': '2024-05-10-18:46:04'},
#                 '__id_in_listings__': {   'avg': 0.7357,
#                                           'exec_count': 50,
#                                           'max': 0.7964,
#                                           'min': 0.6997,
#                                           'std': 0.0247,
#                                           'timestamp': '2024-05-10-18:45:26'}},
#     '2024': {   '__': {   'avg': 0.2575,
#                           'exec_count': 50,
#                           'max': 0.2977,
#                           'min': 0.2401,
#                           'std': 0.0121,
#                           'timestamp': '2024-05-10-18:46:16'},
#                 '__datetime_in_reviews__': {   'avg': 0.0312,
#                                                'exec_count': 50,
#                                                'max': 0.0517,
#                                                'min': 0.0288,
#                                                'std': 0.0031,
#                                                'timestamp': '2024-05-10-18:46:19'},
#                 '__datetime_in_reviews__id_in_listings__': {   'avg': 0.0315,
#                                                                'exec_count': 50,
#                                                                'max': 0.0421,
#                                                                'min': 0.0289,
#                                                                'std': 0.0022,
#                                                                'timestamp': '2024-05-10-18:46:34'},
#                 '__id_in_listings__': {   'avg': 0.26,
#                                           'exec_count': 50,
#                                           'max': 0.3024,
#                                           'min': 0.2451,
#                                           'std': 0.0116,
#                                           'timestamp': '2024-05-10-18:46:32'}}}

# %%
# Extract the avg values for each key inside each year object
def extract_avg_values(data):
    avg_values = {}
    for year, details in data.items():
        avg_values[year] = {}
        for key, metrics in details.items():
            if 'avg' in metrics:
                avg_values[year][key] = metrics['avg']
    return avg_values

# Extract the avg values
avg_values = extract_avg_values(data_listings_renamed)

pp.pprint(avg_values)

# Map the keys to the custom labels
key_labels = {
    "__": "no_index",
    "__datetime_in_reviews__": "datetime_index",
    "__id_in_listings__": "id_index",
    "__datetime_in_reviews__id_in_listings__": "datetime_and_id_index"
}

# Prepare data for DataFrame
data_for_df = {label: [] for label in key_labels.values()}
data_for_df['Year'] = sorted(avg_values.keys())

for year in data_for_df['Year']:
    for key, label in key_labels.items():
        data_for_df[label].append(avg_values[year].get(key, None))

# Create DataFrame
df = pd.DataFrame(data_for_df)

# Set 'Year' as the index
df.set_index('Year', inplace=True)

# Display the DataFrame
print(df)
# Out:
# {   '2009': {   '__': 0.3367,
#                 '__datetime_in_reviews__': 0.0143,
#                 '__datetime_in_reviews__id_in_listings__': 0.0144,
#                 '__id_in_listings__': 0.2337},
#     '2010': {   '__': 0.2415,
#                 '__datetime_in_reviews__': 0.0163,
#                 '__datetime_in_reviews__id_in_listings__': 0.0154,
#                 '__id_in_listings__': 0.2368},
#     '2011': {   '__': 0.2488,
#                 '__datetime_in_reviews__': 0.0168,
#                 '__datetime_in_reviews__id_in_listings__': 0.0169,
#                 '__id_in_listings__': 0.2442},
#     '2012': {   '__': 0.2493,
#                 '__datetime_in_reviews__': 0.02,
#                 '__datetime_in_reviews__id_in_listings__': 0.0193,
#                 '__id_in_listings__': 0.248},
#     '2013': {   '__': 0.2447,
#                 '__datetime_in_reviews__': 0.0238,
#                 '__datetime_in_reviews__id_in_listings__': 0.0246,
#                 '__id_in_listings__': 0.2546},
#     '2014': {   '__': 0.2651,
#                 '__datetime_in_reviews__': 0.0344,
#                 '__datetime_in_reviews__id_in_listings__': 0.0332,
#                 '__id_in_listings__': 0.2552},
#     '2015': {   '__': 0.287,
#                 '__datetime_in_reviews__': 0.0533,
#                 '__datetime_in_reviews__id_in_listings__': 0.054,
#                 '__id_in_listings__': 0.2956},
#     '2016': {   '__': 0.2924,
#                 '__datetime_in_reviews__': 0.0698,
#                 '__datetime_in_reviews__id_in_listings__': 0.0702,
#                 '__id_in_listings__': 0.2938},
#     '2017': {   '__': 0.3071,
#                 '__datetime_in_reviews__': 0.1493,
#                 '__datetime_in_reviews__id_in_listings__': 0.1472,
#                 '__id_in_listings__': 0.3127},
#     '2018': {   '__': 0.6324,
#                 '__datetime_in_reviews__': 0.1925,
#                 '__datetime_in_reviews__id_in_listings__': 0.1954,
#                 '__id_in_listings__': 0.6418},
#     '2019': {   '__': 0.6656,
#                 '__datetime_in_reviews__': 0.2471,
#                 '__datetime_in_reviews__id_in_listings__': 0.2485,
#                 '__id_in_listings__': 0.6747},
#     '2020': {   '__': 0.3097,
#                 '__datetime_in_reviews__': 0.1437,
#                 '__datetime_in_reviews__id_in_listings__': 0.1431,
#                 '__id_in_listings__': 0.3026},
#     '2021': {   '__': 0.6682,
#                 '__datetime_in_reviews__': 0.2252,
#                 '__datetime_in_reviews__id_in_listings__': 0.2226,
#                 '__id_in_listings__': 0.667},
#     '2022': {   '__': 0.7161,
#                 '__datetime_in_reviews__': 0.7292,
#                 '__datetime_in_reviews__id_in_listings__': 0.7106,
#                 '__id_in_listings__': 0.7124},
#     '2023': {   '__': 0.7311,
#                 '__datetime_in_reviews__': 0.725,
#                 '__datetime_in_reviews__id_in_listings__': 0.7345,
#                 '__id_in_listings__': 0.7357},
#     '2024': {   '__': 0.2575,
#                 '__datetime_in_reviews__': 0.0312,
#                 '__datetime_in_reviews__id_in_listings__': 0.0315,
#                 '__id_in_listings__': 0.26}}
#       no_index  datetime_index  id_index  datetime_and_id_index
# Year
# 2009    0.3367          0.0143    0.2337                 0.0144
# 2010    0.2415          0.0163    0.2368                 0.0154
# 2011    0.2488          0.0168    0.2442                 0.0169
# 2012    0.2493          0.0200    0.2480                 0.0193
# 2013    0.2447          0.0238    0.2546                 0.0246
# 2014    0.2651          0.0344    0.2552                 0.0332
# 2015    0.2870          0.0533    0.2956                 0.0540
# 2016    0.2924          0.0698    0.2938                 0.0702
# 2017    0.3071          0.1493    0.3127                 0.1472
# 2018    0.6324          0.1925    0.6418                 0.1954
# 2019    0.6656          0.2471    0.6747                 0.2485
# 2020    0.3097          0.1437    0.3026                 0.1431
# 2021    0.6682          0.2252    0.6670                 0.2226
# 2022    0.7161          0.7292    0.7124                 0.7106
# 2023    0.7311          0.7250    0.7357                 0.7345
# 2024    0.2575          0.0312    0.2600                 0.0315

# %%
# Plotting the data
plt.figure(figsize=(12, 8))

# Plot each category data
for label in key_labels.values():
    plt.plot(df.index, df[label], marker='o', label=label)
    
colors = ['red', 'green', 'blue', 'purple']

# Calculate and plot average lines for each index across all years
for idx, label in enumerate(key_labels.values()):
    avg_value = df[label].mean()
    plt.axhline(y=avg_value, linestyle='--', color=colors[idx], label=f'Average {label}')

plt.title('Average Values per Year')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.grid(True)
plt.show()
